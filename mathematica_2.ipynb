# %%
Plot[Sin[x],{x,0,2*Pi}]
# Out:
# -Graphics-

# %%
Manipulate[
 ContourPlot[
  1/((1 + g*X) \[Sqrt](X^2 + \[Rho]^2)) (
   1 + g*X + 
    g^2 (X^2 + \[Rho]^2)/2)/\[Sqrt](1 + g*X + 
      g^2 (X^2 + \[Rho]^2)/4), {X, -4, 4}, {\[Rho], -4, 4}, 
  PlotLegends -> Automatic, PlotTheme -> "Web", 
  ColorFunction -> ColorData["Rainbow"], 
  PlotLabel -> "\[Phi](X,\[Rho])", AxesLabel -> {X, \[Rho]}], {g, 0, 
  2}]
# Out:
#                                                                 2    2
#                                                              2 X  + ρ
#                                                   1 + g X + g  -------
#                                   1                               2
# Manipulate[ContourPlot[----------------------- --------------------------, {X, -4, 4},
#                                        2    2                     2    2
#                        (1 + g X) Sqrt[X  + ρ ]                 2 X  + ρ
#                                                Sqrt[1 + g X + g  -------]
#                                                                     4
#
# >    {ρ, -4, 4}, PlotLegends -> Automatic, PlotTheme -> Web,
#
# >    ColorFunction -> ColorData[Rainbow], PlotLabel -> ϕ(X,ρ), AxesLabel -> {X, ρ}],
#
# >   {g, 0, 2}]
